# %% [markdown]
# # 9월 20일 소음예측 AI
# <br>
#
# ### 주요 사항
# - 모델 학습 없이 기존 모

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
from keras.models import load_model
import datetime
from scipy.io import wavfile
from sklearn.preprocessing import StandardScaler
from pydub import AudioSegment
from scipy.signal import resample
import IPython.display as ipd

# %%
uploaded_file_name = 'test.wav'
EXPECTED_SAMPLE_RATE = 44100 #44.1KHz

def convert_audio_for_model(user_file, output_file = 'converted_audio_file.wav'):
    audio = AudioSegment.from_file(user_file, format = "wav")
    audio = audio.set_frame_rate(EXPECTED_SAMPLE_RATE).set_channels(1)
    audio.export(output_file, format="wav")
    return output_file

converted_audio_file = convert_audio_for_model(uploaded_file_name)

ipd.Audio(converted_audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Loading audio samples from the wav file : 
sample_rate, audio_samples = wavfile.read(converted_audio_file, 'rb')

# 오디오 정보 출력
duration = len(audio_samples)/sample_rate
print("data :", audio_samples)
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(audio_samples)}')
# Out:
# data : [ 1025  3071  5121 ... -5628 -3588 -1534]
# Sample rate: 44100 Hz
# Total duration: 5.75s
# Size of the input: 253440

# %%
# csv파일 불러오기
pd.DataFrame(audio_samples).to_csv("test.csv")
data = pd.read_csv('test.csv')
# train_data = data['0'].values/1000

# data 정보 출력
print(data['0'].describe())
# train data 그래프 출력
plt.plot(data['0'])
plt.xlim(0,1000)
plt.legend()
plt.show()
data
# Out:
# No handles with labels found to put in legend.
# count    253440.000000
# mean          0.022727
# std       13317.174470
# min      -22273.000000
# 25%      -11454.500000
# 50%         127.000000
# 75%       11585.000000
# max       22271.000000
# Name: 0, dtype: float64
#         Unnamed: 0     0
# 0                0  1025
# 1                1  3071
# 2                2  5121
# 3                3  7168
# 4                4  9215
# ...            ...   ...
# 253435      253435 -9724
# 253436      253436 -7684
# 253437      253437 -5628
# 253438      253438 -3588
# 253439      253439 -1534
#
# [253440 rows x 2 columns]

# %%
X = np.arange(len(data)).reshape(-1,1)
y = data['0'].values
y = y.reshape(-1,1)
print("X : \n", X)
print("\ny : \n", y)
# Out:
# X :
#  [[     0]
#  [     1]
#  [     2]
#  ...
#  [253437]
#  [253438]
#  [253439]]
#
# y :
#  [[ 1025]
#  [ 3071]
#  [ 5121]
#  ...
#  [-5628]
#  [-3588]
#  [-1534]]

# %%
# 딥러닝 학습을 정상적으로 동작 시키기 위해 데이터 정규화
y_std = y.std()
y_mean = y.mean()
y = (y-y_mean) / y_std
y
# Out:
# array([[ 0.07696672],
#        [ 0.23060322],
#        [ 0.38454008],
#        ...,
#        [-0.42261471],
#        [-0.26942876],
#        [-0.11519153]])

# %%
seq_len = 50   #window size : 예측을 위한 데이터 수
prediction = 1  # 다음을 예측할 데이터 수
sequence_length = seq_len + prediction

result = []
for index in range(len(y) - sequence_length):
    result.append(y[index: index + sequence_length])

# %%
result = np.array(result)
row = int(round(result.shape[0] * 0.7))
train = result[:row, :]

# %%
# 현재를 기준으로 최근 50개 데이터를 시험에 사용하고 그 외의 이전 데이터들은 학습에 사용
test_period = 50

X_train = train[:, :-prediction]
y_train = train[:,-prediction]
X_test = result[row:, :-prediction]
y_test = result[row:, -prediction]

print("shape of X_train : ", X_train.shape)
print("shape of y_train : ", y_train.shape)
print("shape of X_test : ", X_test.shape)
print("shape of y_test : ", y_test.shape)
# Out:
# shape of X_train :  (177372, 50, 1)
# shape of y_train :  (177372, 1)
# shape of X_test :  (76017, 50, 1)
# shape of y_test :  (76017, 1)

# %%
# 학습데이터 : 검증데이터 = 7 : 3  (학습이 진행되는 중에도 학습이 정상적으로 이루어지는지 확인하기 위함)
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=0)

# %%
# tensorflow에 데이터를 전달하기 전에 입력 형식을 맞추기 위해 2차원 데이터를 3차원 데이터로 변환
X = X.reshape(X.shape[0], X.shape[1], 1)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

print("shape of X : ", X.shape)  # data 수 
print("shape of X_train : ", X_train.shape)  # (data 수 - test_period)의 70%
print("shape of X_val : ", X_val.shape)  # (data 수 - test_period)의 30%
print("shape of X_test : ", X_test.shape)  # test_period
# Out:
# shape of X :  (253440, 1, 1)
# shape of X_train :  (124160, 50, 1)
# shape of X_val :  (53212, 50, 1)
# shape of X_test :  (76017, 50, 1)

# %%
# 모델 생성
print('Build LSTM RNN model ...')
model = Sequential()

# LSTM layer
model.add(LSTM(50, return_sequences=True, input_shape=(50,1)))  # (timestep, feature)
model.add(LSTM(64, return_sequences=False))

# Output(Dense) : 1개 
model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='rmsprop')
model.summary()
# Out:
# Build LSTM RNN model ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 39,905
# Trainable params: 39,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time 
# 트레이닝 값으로 학습
print ("training started..... please wait.")
hist = model.fit(X_train, y_train, epochs = 5, batch_size=10, validation_data=(X_val, y_val))

# 모델 저장
model.save('weight.h5')
print ("training finised!")
# Out:
# training started..... please wait.
# Epoch 1/5
# 12416/12416 [==============================] - 651s 52ms/step - loss: 0.0056 - val_loss: 1.6453e-04
# Epoch 2/5
# 12416/12416 [==============================] - 755s 61ms/step - loss: 1.7751e-04 - val_loss: 1.8184e-04
# Epoch 3/5
# 12416/12416 [==============================] - 9089s 732ms/step - loss: 9.6314e-05 - val_loss: 1.8040e-05
# Epoch 4/5
# 12416/12416 [==============================] - 682s 55ms/step - loss: 6.9992e-05 - val_loss: 6.9201e-05
# Epoch 5/5
# 12416/12416 [==============================] - 723s 58ms/step - loss: 5.7473e-05 - val_loss: 5.2650e-05
# training finised!
# Wall time: 3h 18min 19s

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
trainScore = model.evaluate(X_train, y_train, verbose=0)
valScore = model.evaluate(X_val, y_val, verbose=0)
testScore = model.evaluate(X_test, y_test, verbose=0)

print('Train Score : ', trainScore)
print('Validation Score : ', valScore)
print('Test Score : ', testScore)
# Out:
# Train Score :  5.271535337669775e-05
# Validation Score :  5.264994251774624e-05
# Test Score :  5.269864414003678e-05

# %%
pred = model.predict(X_test)  # 모델을 사용하여 예측한다

# %%
fig = plt.figure(facecolor='white', figsize=(20, 10))
ax = fig.add_subplot(111)
ax.plot(y_test, label='True')
ax.plot(pred, '.', label='Prediction')
ax.legend()
plt.xlim(1,1000)
plt.show()

# %%
# 정규화된 데이터를 복원하기 위해 사용하는 함수
def denorm(y):
    return y * y_std + y_mean

fig = plt.figure(facecolor='white', figsize=(20, 10))
ax = fig.add_subplot(111)
ax.plot(denorm(y_test), label='True (denorm)')
ax.plot(denorm(pred), '.', label='Prediction (denorm)')
ax.legend()
plt.xlim(0,1000)
plt.show()

# %%
# 정규화 됐던 pred를 복원 
pred = denorm(pred)

# %%
wavfile.write("pred.wav", EXPECTED_SAMPLE_RATE, pred)

# %%
ipd.Audio("pred.wav")
# 5초짜리 test -> 1초짜리 pred?
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = AudioSegment.from_file("pred.wav", format = "wav")
audio = audio.set_frame_rate(EXPECTED_SAMPLE_RATE).set_channels(1)
audio.export("pred_converted.wav", format="wav")

# Loading audio samples from the wav file : 
pred_sample_rate, pred_audio_samples = wavfile.read("pred_converted.wav", 'rb')

# 오디오 정보 출력
pred_duration = len(pred_audio_samples)/pred_sample_rate
print("data :", pred_audio_samples)
print(f'Sample rate: {pred_sample_rate} Hz')
print(f'Total duration: {pred_duration:.2f}s')
print(f'Size of the input: {len(pred_audio_samples)}')
# Out:
# data : [ 2147483647  2147483647  2147483647 ... -2147483648 -2147483648
#  -2147483648]
# Sample rate: 44100 Hz
# Total duration: 1.72s
# Size of the input: 76017

# %%
ipd.Audio("pred.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pred
# Out:
# array([[ 2.1368152e+08],
#        [ 1.8532771e+08],
#        [ 1.5870250e+08],
#        ...,
#        [-1.0320032e+08],
#        [-7.6148456e+07],
#        [-4.8771152e+07]], dtype=float32)

# %%
# csv파일 불러오기
pd.DataFrame(pred_audio_samples).to_csv("pred.csv")
pred_data = pd.read_csv('pred.csv')
print("pred_data :", pred_audio_samples)
# data 정보 출력
print(pred_data['0'].describe())
# train data 그래프 출력
plt.plot(pred_data['0'])
plt.xlim(0,1000)
plt.legend()
plt.show()
pred_data
# Out:
# No handles with labels found to put in legend.
# pred_data : [ 2147483647  2147483647  2147483647 ... -2147483648 -2147483648
#  -2147483648]
# count    7.601700e+04
# mean    -3.672511e+05
# std      2.147498e+09
# min     -2.147484e+09
# 25%     -2.147484e+09
# 50%     -2.147484e+09
# 75%      2.147484e+09
# max      2.147484e+09
# Name: 0, dtype: float64
#        Unnamed: 0           0
# 0               0  2147483647
# 1               1  2147483647
# 2               2  2147483647
# 3               3  2147483647
# 4               4  2147483647
# ...           ...         ...
# 76012       76012 -2147483648
# 76013       76013 -2147483648
# 76014       76014 -2147483648
# 76015       76015 -2147483648
# 76016       76016 -2147483648
#
# [76017 rows x 2 columns]
